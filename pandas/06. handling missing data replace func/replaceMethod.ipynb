# %% [markdown]
# <div style="text-align: center;">
#     <h1>Handling Missing Data - replace method.</h1>
# </div>

# %%
import pandas as pd  
import numpy as np
df = pd.read_csv("weather_data.csv")
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       -99999          7  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %% [markdown]
# Replacing single value.

# %%
new_df = df.replace(-99999, value=np.nan)
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0      0
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0      0

# %% [markdown]
# Replacing list with single value

# %%
new_df = df.replace(to_replace=[-99999, -88888], value=0)
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017            0          7  Sunny
# 2  1/3/2017           28          0   Snow
# 3  1/4/2017            0          7      0
# 4  1/5/2017           32          0   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %% [markdown]
# Replacing per column

# %%
new_df = df.replace({
    'temperature': -99999,
    'windspeed': -99999,
    'event': '0'
}, np.nan)

new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0    NaN
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0    NaN

# %% [markdown]
# Replace by using mapping

# %%
new_df = df.replace({
    -99999: np.nan,
    'no event': 'Sunny',
})
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0      0
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0      0

# %% [markdown]
# Regex

# %%
# when windspeed is 6 mph, 7 mph etc. & temperature is 32 F, 28 F etc.
# regex means regula expression
new_df = df.replace({
    'temperature': '[A-Za-z]',
    'windspeed': '[a-z]'
}, '', regex=True)
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       -99999          7  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %% [markdown]
# Regular Expressions (aka regex) are powerful tools used to search, match, and manipulate strings using specific patterns. They’re commonly used in data cleaning, validation, and text processing.
#
# ###  TL;DR
#
# Regex is like a language for patterns in text.

# %% [markdown]
# Replacing list with another list

# %%
df = pd.DataFrame({
    'score': ['exceptional', 'average', 'good', 'poor', 'average', 'exceptional'],
    'student': ['rob', 'maya', 'alex', 'tom', 'julian', 'erica']
})
df
# Out:
#          score student
# 0  exceptional     rob
# 1      average    maya
# 2         good    alex
# 3         poor     tom
# 4      average  julian
# 5  exceptional   erica

# %%
df.replace(['poor', 'average', 'good', 'exceptional'], [1, 2, 3, 4])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_5056\1071936032.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(['poor', 'average', 'good', 'exceptional'], [1, 2, 3, 4])
#    score student
# 0      4     rob
# 1      2    maya
# 2      3    alex
# 3      1     tom
# 4      2  julian
# 5      4   erica
